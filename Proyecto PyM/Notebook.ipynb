# %% [markdown]
# # Avance 3

# %%
from Tools import tools as t

# %%
t.inicializar_bdd()
t.generar_bdd_rango('2025-01-01', '2025-01-31')
# Out:
# Base de datos creada/conectada
# Tabla creada
# Estás insertando info de un rango fechas :D
# Comienzo del programa .....
# Generación exitosa al 2025-01-01 con 71 ventas
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-02 con 71 ventas
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-03 con 71 ventas
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-04 con 71 ventas
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-05 con 71 ventas
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-06 con 71 ventas
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-07 con 71 ventas
# ...

# %%
query = """
SELECT 
    * 
FROM 
    Ventas
LIMIT
    10
"""

t.consultar(query)
# Out:
#         Fecha    Sucursal    Producto Clave_Producto   Precio  \
# 0  2025-01-01    Santa Fé    Pinturas        HIX-345  2007.18
# 1  2025-01-01      Zócalo    Mochilas        EDE-495  6911.70
# 2  2025-01-01  Milpa Alta          Pc        NPD-486  1234.51
# 3  2025-01-01      Centro  Cargadores        NUU-712  2787.79
# 4  2025-01-01  Milpa Alta    Pinturas        HKJ-692  7216.95
# 5  2025-01-01          CU          Pc        QPB-826  4272.52
# 6  2025-01-01    Narvarte  Sacapuntas        LVG-178  9041.84
# 7  2025-01-01      Centro   Cuadernos        FQB-314  9533.63
# 8  2025-01-01          CU  Sacapuntas        UVT-533  8475.74
# 9  2025-01-01    Cuemanco   Cuadernos        UTJ-719  2653.79
#
#    Cantidad_Vendida  Total_Ticket
# 0               409     820936.62
# 1               819    5660682.30
# 2               556     686387.56
# 3               593    1653159.47
# 4               305    2201169.75
# 5               999    4268247.48
# 6               300    2712552.00
# ...
